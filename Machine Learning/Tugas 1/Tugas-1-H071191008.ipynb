# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv('Groceries_dataset.csv') #Read data dari csv file
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df.shape # Mencari jumlah baris dan kolom dari data frame
# Out:
# (38765, 3)

# %%
df.columns # Mencari label dari tiap kolom
# Out:
# Index(['Member_number', 'Date', 'itemDescription'], dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date']) # format tanggal pada label "Date"
df['Member_number'].nunique() # format unik pada label "Member_number"
df.head()
# Out:
#    Member_number       Date   itemDescription
# 0           1808 2015-07-21    tropical fruit
# 1           2552 2015-05-01        whole milk
# 2           2300 2015-09-19         pip fruit
# 3           1187 2015-12-12  other vegetables
# 4           3037 2015-01-02        whole milk

# %%
df['itemDescription'] = df['itemDescription'].str.strip() # Mengilangkan spasi pada awal atau akhir "itemDescription" jika ada
df['itemDescription'] = df['itemDescription'].str.lower() # Mengubah "itemDescription" menjadi lowercase
df.head()
# Out:
#    Member_number       Date   itemDescription
# 0           1808 2015-07-21    tropical fruit
# 1           2552 2015-05-01        whole milk
# 2           2300 2015-09-19         pip fruit
# 3           1187 2015-12-12  other vegetables
# 4           3037 2015-01-02        whole milk

# %%
# Mapping "itemDescription" menggunakan "Member_number" dan "Date"
# hasil ini akan menampilkan "itemDescription" pada satu baris berdasarkan "Member_numbera" dan "Date"

df['itemDescription'] = df.groupby(['Member_number', 'Date'])['itemDescription'].transform(lambda x: ','.join(x))
df
# Out:
#        Member_number       Date                          itemDescription
# 0               1808 2015-07-21          tropical fruit,rolls/buns,candy
# 1               2552 2015-05-01      whole milk,tropical fruit,chocolate
# 2               2300 2015-09-19         pip fruit,other vegetables,flour
# 3               1187 2015-12-12    other vegetables,onions,shopping bags
# 4               3037 2015-01-02  whole milk,other vegetables,white bread
# ...              ...        ...                                      ...
# 38760           4471 2014-08-10          whole milk,yogurt,sliced cheese
# 38761           2022 2014-02-23                    cat food,yogurt,candy
# 38762           1097 2014-04-16              sausage,whole milk,cake bar
# 38763           1510 2014-03-12   beef,canned beer,fruit/vegetable juice
# 38764           1521 2014-12-26           ham,seasonal products,cat food
#
# [38765 rows x 3 columns]

# %%
# Menggunakan perulangan untuk memisahkan setiap item berdasarkan karakter ','
lst=[]
for i in range(0,len(df)-1):    
    data = df['itemDescription'][i].split(',')
    lst.append(data)

# %%
# Menggunakan dungsi TransactionEncoder untuk mengubah data_frame menggunakan list sebelumnya
# kemudian mengubahnya lagi menjadi data_frame
te = TransactionEncoder()
te_ary = te.fit(lst).transform(lst)
df_new = pd.DataFrame(te_ary, columns=te.columns_)
df_new
# Out:
#        abrasive cleaner  artif. sweetener  baby cosmetics   bags  \
# 0                 False             False           False  False
# 1                 False             False           False  False
# 2                 False             False           False  False
# 3                 False             False           False  False
# 4                 False             False           False  False
# ...                 ...               ...             ...    ...
# 38759             False             False           False  False
# 38760             False             False           False  False
# 38761             False             False           False  False
# 38762             False             False           False  False
# 38763             False             False           False  False
#
#        baking powder  bathroom cleaner   beef  berries  beverages  \
# 0              False             False  False    False      False
# 1              False             False  False    False      False
# 2              False             False  False    False      False
# 3              False             False  False    False      False
# 4              False             False  False    False      False
# ...              ...               ...    ...      ...        ...
# 38759          False             False   True    False      False
# 38760          False             False  False    False      False
# 38761          False             False  False    False      False
# 38762          False             False  False    False      False
# 38763          False             False   True    False      False
#
#        bottled beer  ...  uht-milk  vinegar  waffles  whipped/sour cream  \
# 0             False  ...     False    False    False               False
# 1             False  ...     False    False    False               False
# 2             False  ...     False    False    False               False
# 3             False  ...     False    False    False               False
# 4             False  ...     False    False    False               False
# ...             ...  ...       ...      ...      ...                 ...
# 38759         False  ...     False    False    False               False
# 38760         False  ...     False    False    False               False
# 38761         False  ...     False    False    False               False
# 38762         False  ...     False    False    False               False
# 38763         False  ...     False    False    False               False
#
#        whisky  white bread  white wine  whole milk  yogurt  zwieback
# 0       False        False       False       False   False     False
# 1       False        False       False        True   False     False
# 2       False        False       False       False   False     False
# 3       False        False       False       False   False     False
# 4       False         True       False        True   False     False
# ...       ...          ...         ...         ...     ...       ...
# 38759   False        False       False       False   False     False
# 38760   False        False       False        True    True     False
# 38761   False        False       False       False    True     False
# 38762   False        False       False        True   False     False
# 38763   False        False       False       False   False     False
#
# [38764 rows x 167 columns]

# %%
# Mencari nilai support dengan standar 0.02

frq_items = apriori(df_new, min_support=0.02,use_colnames=True)
frq_items
# Out:
#      support                        itemsets
# 0   0.039624                          (beef)
# 1   0.024739                       (berries)
# 2   0.054742                  (bottled beer)
# 3   0.069497                 (bottled water)
# 4   0.044165                   (brown bread)
# 5   0.041895                        (butter)
# 6   0.020586                   (butter milk)
# 7   0.055954                   (canned beer)
# 8   0.033072                       (chicken)
# 9   0.028093                     (chocolate)
# 10  0.060649                  (citrus fruit)
# 11  0.036658                        (coffee)
# 12  0.027035                  (cream cheese)
# 13  0.040914                          (curd)
# 14  0.026029                       (dessert)
# 15  0.044139                 (domestic eggs)
# 16  0.047983                   (frankfurter)
# 17  0.020638                  (frozen meals)
# 18  0.033201             (frozen vegetables)
# 19  0.040140         (fruit/vegetable juice)
# 20  0.025384                (hamburger meat)
# 21  0.021128      (long life bakery product)
# 22  0.038464                     (margarine)
# 23  0.026287                       (napkins)
# 24  0.046048                    (newspapers)
# 25  0.023140                        (onions)
# 26  0.137679              (other vegetables)
# 27  0.060623                        (pastry)
# 28  0.057708                     (pip fruit)
# 29  0.043778                          (pork)
# 30  0.127954                    (rolls/buns)
# 31  0.079404               (root vegetables)
# 32  0.022289                   (salty snack)
# 33  0.074580                       (sausage)
# 34  0.056444                 (shopping bags)
# 35  0.112269                          (soda)
# 36  0.021128                         (sugar)
# 37  0.079326                (tropical fruit)
# 38  0.024533                      (uht-milk)
# 39  0.022315                       (waffles)
# 40  0.048344            (whipped/sour cream)
# 41  0.028841                   (white bread)
# 42  0.183753                    (whole milk)
# 43  0.101434                        (yogurt)
# 44  0.022340  (other vegetables, whole milk)
# 45  0.022237        (whole milk, rolls/buns)

# %%
rules = association_rules(frq_items, metric = "confidence", min_threshold = 0.1)
rules
# Out:
#           antecedents         consequents  antecedent support  \
# 0  (other vegetables)        (whole milk)            0.137679
# 1        (whole milk)  (other vegetables)            0.183753
# 2        (whole milk)        (rolls/buns)            0.183753
# 3        (rolls/buns)        (whole milk)            0.127954
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.183753  0.022340    0.162263  0.883052 -0.002959    0.974348
# 1            0.137679  0.022340    0.121578  0.883052 -0.002959    0.981670
# 2            0.127954  0.022237    0.121016  0.945782 -0.001275    0.992108
# 3            0.183753  0.022237    0.173790  0.945782 -0.001275    0.987942
